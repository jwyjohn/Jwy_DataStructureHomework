# %%
from random import randint
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import time
import os
import matplotlib

# %%
def gen_data(n,m,filename):
    a = [randint(1,2*n) for i in range(n)]
    q1 = [randint(1,n) for i in range(m)]
    q2 = [randint(1,n) for i in range(m)]
    q = [(min(q1[i],q2[i]),max(q1[i],q2[i])) for i in range(m)]
    with open(filename,'w') as f:
        f.write("{} {}\n".format(n,m))
        for i in a:
            f.write("{}\n".format(i))
        for i in q:
            f.write("{} {}\n".format(i[0],i[1]))

# %%
gen_data(10,100,'test.in')

# %%
start_t = time.time_ns()
os.system("sleep 1")
end_t = time.time_ns()
print(end_t-start_t)
# Out:
# 1007163702

# %%
def test_algo(n,m,srcfile):
    os.system("rm -f test.in test.out a.out")
    gen_data(n,m,'test.in')
    cmd0 = "g++ {}".format(srcfile)
    cmd1 = "./a.out < test.in > test.out"
    os.system(cmd0)
    start_t = time.time_ns()
    os.system(cmd1)
    end_t = time.time_ns()
    # print(end_t-start_t)
    os.system("rm -f test.in test.out a.out")
    return (end_t-start_t)

# %%
test_algo(100000,10000,"Seg_tree.cpp")
# Out:
# 20264898

# %%
test_algo(100000,10000,"Prefix_array.cpp")
# Out:
# 12522355

# %%
test_algo(100000,10000,"Plain_array.cpp")
# Out:
# 452008311

# %%
src_list = glob("*.cpp")
src_list
# Out:
# ['Block_array.cpp',
#  'Plain_array.cpp',
#  'BIT_array.cpp',
#  'Seg_tree.cpp',
#  'Prefix_array.cpp']

# %%
N = [round(10000*1.3**i) for i in range(25)]
N
# Out:
# [10000,
#  13000,
#  16900,
#  21970,
#  28561,
#  37129,
#  48268,
#  62749,
#  81573,
#  106045,
#  137858,
#  179216,
#  232981,
#  302875,
#  393738,
#  511859,
#  665417,
#  865042,
#  1124554,
#  1461920,
#  1900496,
#  2470645,
#  3211839,
#  4175391,
#  5428008]

# %%
M = 10000
res = {i:[] for i in src_list}
for s in src_list:
    for n in N:
        tmp = test_algo(n,n,s)
        print(s,n,tmp)
        res[s].append((n,tmp))
# Out:
# Block_array.cpp 10000 8065451
# Block_array.cpp 13000 8160182
# Block_array.cpp 16900 9004420
# Block_array.cpp 21970 9645951
# Block_array.cpp 28561 10509700
# Block_array.cpp 37129 11597389
# Block_array.cpp 48268 13098811
# Block_array.cpp 62749 14396645
# Block_array.cpp 81573 16522921
# Block_array.cpp 106045 19129841
# Block_array.cpp 137858 23416131
# Block_array.cpp 179216 26162104
# Block_array.cpp 232981 30897736
# Block_array.cpp 302875 37275022
# Block_array.cpp 393738 44040510
# Block_array.cpp 511859 54135838
# Block_array.cpp 665417 67249552
# Block_array.cpp 865042 84381523
# Block_array.cpp 1124554 104036717
# Block_array.cpp 1461920 129041999
# Block_array.cpp 1900496 159795742
# Block_array.cpp 2470645 198488696
# Block_array.cpp 3211839 248198155
# Block_array.cpp 4175391 314619771
# Block_array.cpp 5428008 400801664
# Plain_array.cpp 10000 61165329
# Plain_array.cpp 13000 74056149
# Plain_array.cpp 16900 92907150
# Plain_array.cpp 21970 115218285
# Plain_array.cpp 28561 141726053
# Plain_array.cpp 37129 181584336
# Plain_array.cpp 48268 230760711
# Plain_array.cpp 62749 293176906
# Plain_array.cpp 81573 376283194
# Plain_array.cpp 106045 480688003
# Plain_array.cpp 137858 616458329
# Plain_array.cpp 179216 800537133
# Plain_array.cpp 232981 1049581534
# Plain_array.cpp 302875 1357940756
# Plain_array.cpp 393738 1768518125
# Plain_array.cpp 511859 2278659298
# Plain_array.cpp 665417 2948286218
# Plain_array.cpp 865042 3819970350
# Plain_array.cpp 1124554 5011367093
# Plain_array.cpp 1461920 6533819754
# Plain_array.cpp 1900496 8628494827
# Plain_array.cpp 2470645 11239240552
# Plain_array.cpp 3211839 14767855710
# Plain_array.cpp 4175391 18823989542
# Plain_array.cpp 5428008 24899336894
# BIT_array.cpp 10000 17854162
# BIT_array.cpp 13000 18437414
# BIT_array.cpp 16900 18831078
# BIT_array.cpp 21970 19392621
# BIT_array.cpp 28561 20265035
# BIT_array.cpp 37129 21077970
# BIT_array.cpp 48268 22412062
# BIT_array.cpp 62749 23913277
# BIT_array.cpp 81573 26074632
# BIT_array.cpp 106045 28895055
# BIT_array.cpp 137858 32432890
# BIT_array.cpp 179216 36736264
# BIT_array.cpp 232981 42493963
# BIT_array.cpp 302875 49944052
# BIT_array.cpp 393738 60124009
# BIT_array.cpp 511859 71770263
# BIT_array.cpp 665417 89849817
# BIT_array.cpp 865042 113217582
# BIT_array.cpp 1124554 140522449
# BIT_array.cpp 1461920 176489880
# BIT_array.cpp 1900496 220986102
# BIT_array.cpp 2470645 283488174
# BIT_array.cpp 3211839 357500354
# BIT_array.cpp 4175391 447520102
# BIT_array.cpp 5428008 581567084
# Seg_tree.cpp 10000 10335522
# Seg_tree.cpp 13000 11148424
# Seg_tree.cpp 16900 11715175
# Seg_tree.cpp 21970 11997491
# Seg_tree.cpp 28561 13052370
# Seg_tree.cpp 37129 14190871
# Seg_tree.cpp 48268 15119217
# Seg_tree.cpp 62749 16690904
# Seg_tree.cpp 81573 19285940
# Seg_tree.cpp 106045 20724728
# Seg_tree.cpp 137858 24583447
# Seg_tree.cpp 179216 28660965
# Seg_tree.cpp 232981 32515068
# Seg_tree.cpp 302875 39713647
# Seg_tree.cpp 393738 46756081
# Seg_tree.cpp 511859 55319245
# Seg_tree.cpp 665417 72757734
# Seg_tree.cpp 865042 87976843
# Seg_tree.cpp 1124554 120308148
# Seg_tree.cpp 1461920 141286163
# Seg_tree.cpp 1900496 171060370
# Seg_tree.cpp 2470645 226557818
# Seg_tree.cpp 3211839 277284840
# Seg_tree.cpp 4175391 345527368
# Seg_tree.cpp 5428008 469785382
# Prefix_array.cpp 10000 27492995
# Prefix_array.cpp 13000 27831159
# Prefix_array.cpp 16900 27909726
# Prefix_array.cpp 21970 28312823
# Prefix_array.cpp 28561 28684518
# Prefix_array.cpp 37129 28930899
# Prefix_array.cpp 48268 29631180
# Prefix_array.cpp 62749 30443822
# Prefix_array.cpp 81573 32070887
# Prefix_array.cpp 106045 33308557
# Prefix_array.cpp 137858 35163196
# Prefix_array.cpp 179216 37546573
# Prefix_array.cpp 232981 40304142
# Prefix_array.cpp 302875 44302300
# Prefix_array.cpp 393738 49103427
# Prefix_array.cpp 511859 55854719
# Prefix_array.cpp 665417 68541970
# Prefix_array.cpp 865042 79462931
# Prefix_array.cpp 1124554 95415503
# Prefix_array.cpp 1461920 114674188
# Prefix_array.cpp 1900496 140077408
# Prefix_array.cpp 2470645 178530072
# Prefix_array.cpp 3211839 213544454
# Prefix_array.cpp 4175391 268071644
# Prefix_array.cpp 5428008 342635453

# %%
res
# Out:
# {'Block_array.cpp': [(10000, 8065451),
#   (13000, 8160182),
#   (16900, 9004420),
#   (21970, 9645951),
#   (28561, 10509700),
#   (37129, 11597389),
#   (48268, 13098811),
#   (62749, 14396645),
#   (81573, 16522921),
#   (106045, 19129841),
#   (137858, 23416131),
#   (179216, 26162104),
#   (232981, 30897736),
#   (302875, 37275022),
#   (393738, 44040510),
#   (511859, 54135838),
#   (665417, 67249552),
#   (865042, 84381523),
#   (1124554, 104036717),
#   (1461920, 129041999),
#   (1900496, 159795742),
#   (2470645, 198488696),
#   (3211839, 248198155),
#   (4175391, 314619771),
#   (5428008, 400801664)],
#  'Plain_array.cpp': [(10000, 61165329),
#   (13000, 74056149),
#   (16900, 92907150),
#   (21970, 115218285),
#   (28561, 141726053),
#   (37129, 181584336),
#   (48268, 230760711),
#   (62749, 293176906),
#   (81573, 376283194),
#   (106045, 480688003),
#   (137858, 616458329),
#   (179216, 800537133),
#   (232981, 1049581534),
#   (302875, 1357940756),
#   (393738, 1768518125),
#   (511859, 2278659298),
#   (665417, 2948286218),
#   (865042, 3819970350),
#   (1124554, 5011367093),
#   (1461920, 6533819754),
#   (1900496, 8628494827),
#   (2470645, 11239240552),
#   (3211839, 14767855710),
#   (4175391, 18823989542),
#   (5428008, 24899336894)],
#  'BIT_array.cpp': [(10000, 17854162),
#   (13000, 18437414),
#   (16900, 18831078),
#   (21970, 19392621),
#   (28561, 20265035),
#   (37129, 21077970),
#   (48268, 22412062),
#   (62749, 23913277),
#   (81573, 26074632),
#   (106045, 28895055),
#   (137858, 32432890),
#   (179216, 36736264),
#   (232981, 42493963),
#   (302875, 49944052),
#   (393738, 60124009),
#   (511859, 71770263),
#   (665417, 89849817),
#   (865042, 113217582),
#   (1124554, 140522449),
#   (1461920, 176489880),
#   (1900496, 220986102),
#   (2470645, 283488174),
#   (3211839, 357500354),
#   (4175391, 447520102),
#   (5428008, 581567084)],
#  'Seg_tree.cpp': [(10000, 10335522),
#   (13000, 11148424),
#   (16900, 11715175),
#   (21970, 11997491),
#   (28561, 13052370),
#   (37129, 14190871),
#   (48268, 15119217),
#   (62749, 16690904),
#   (81573, 19285940),
#   (106045, 20724728),
#   (137858, 24583447),
#   (179216, 28660965),
#   (232981, 32515068),
#   (302875, 39713647),
#   (393738, 46756081),
#   (511859, 55319245),
#   (665417, 72757734),
#   (865042, 87976843),
#   (1124554, 120308148),
#   (1461920, 141286163),
#   (1900496, 171060370),
#   (2470645, 226557818),
#   (3211839, 277284840),
#   (4175391, 345527368),
#   (5428008, 469785382)],
#  'Prefix_array.cpp': [(10000, 27492995),
#   (13000, 27831159),
#   (16900, 27909726),
#   (21970, 28312823),
#   (28561, 28684518),
#   (37129, 28930899),
#   (48268, 29631180),
#   (62749, 30443822),
#   (81573, 32070887),
#   (106045, 33308557),
#   (137858, 35163196),
#   (179216, 37546573),
#   (232981, 40304142),
#   (302875, 44302300),
#   (393738, 49103427),
#   (511859, 55854719),
#   (665417, 68541970),
#   (865042, 79462931),
#   (1124554, 95415503),
#   (1461920, 114674188),
#   (1900496, 140077408),
#   (2470645, 178530072),
#   (3211839, 213544454),
#   (4175391, 268071644),
#   (5428008, 342635453)]}

# %%
plt.style.use('default')

# %%
dpi = 300
fig = plt.figure(figsize=(20, 9), dpi=dpi)
plt.grid(True, lw = 0.5, ls = '--', c = '.65',which='both')
plt.xlabel('N')
plt.ylabel('Time')
for i in res.items():
    tx = [j[0] for j in i[1]]
    ty = [j[1] for j in i[1]]
    plt.loglog(tx,ty,label=i[0])
plt.legend()
fig.show()
# Out:
# /tmp/ipykernel_46210/3326183554.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dpi = 300
fig = plt.figure(figsize=(20, 9), dpi=dpi)
plt.grid(True, lw = 0.5, ls = '--', c = '.65',which='both')
plt.xlabel('N')
plt.ylabel('Time')
for i in res.items():
    if (i[0] == 'Plain_array.cpp'):
        continue
    tx = [j[0] for j in i[1]]
    ty = [j[1] for j in i[1]]
    plt.loglog(tx,ty,label=i[0])
plt.legend()
fig.show()
# Out:
# /tmp/ipykernel_46210/2829562163.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
dpi = 300
matplotlib.use('Agg')
fig = plt.figure(figsize=(20, 9), dpi=dpi)
plt.grid(True, lw = 0.5, ls = '--', c = '.65',which='both')
plt.xlabel('N')
plt.ylabel('Time')
for i in res.items():
    tx = [j[0] for j in i[1]]
    ty = [j[1] for j in i[1]]
    plt.loglog(tx,ty,label=i[0])
plt.legend()
plt.savefig('performance1.eps',format='eps')
matplotlib.use('TkAgg')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
